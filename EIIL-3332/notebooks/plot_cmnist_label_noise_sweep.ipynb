# %% [markdown]
# <a href="https://colab.research.google.com/github/ecreager/eiil_dev/blob/public/notebooks/plot_cmnist_label_noise_sweep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Plot results from CMNIST label noise sweep experiments.

See  exps/cmnist.label_noise_sweep.sh for reproducing results.
"""
from collections import defaultdict
from glob import glob
import os
import pickle
from pprint import pprint

import matplotlib.pyplot as plt

def load_results(dirname):
  return pickle.load(open(os.path.join(dirname, 'metrics.p'), 'rb'))
  
def load_flags(dirname):
  return pickle.load(open(os.path.join(dirname, 'flags.p'), 'rb'))

# GLOB_PATTERNS = dict(}
#   irm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/irm',
#   erm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/erm',
#   eiil='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil',
#   eiil_cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil_cb',
#   cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/cb',
#   gray='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/gray',
# )

GLOB_PATTERNS = dict(
  irm='/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05*/irm',
  erm='/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05*/erm',
  eiil='/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05*/eiil',
  eiil_infer='/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05*/eiil_infer',
  gray='/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05*/gray',
)
train_accs = defaultdict(dict)
test_accs = defaultdict(dict)
label_noises = set()

for k, v in GLOB_PATTERNS.items():
  print(k)
  pprint(glob(v))
  for dn in glob(v):
    try:
      results = load_results(dn)
      flags = load_flags(dn)
    except:
      print('no metrics or no flags found in', dn)
    label_noises.add(flags.label_noise)
    pprint(flags)
    train_accs[k][flags.label_noise] = results['Train accs']
    test_accs[k][flags.label_noise] = results['Test accs']

label_noises = sorted(label_noises)
# Out:
# irm
# ['/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.10\\irm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.15\\irm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.20\\irm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.25\\irm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.30\\irm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.35\\irm']
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.10/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.15/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.20/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.25/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.30/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=1, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.35/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# erm
# ['/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.10\\erm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.15\\erm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.20\\erm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.25\\erm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.30\\erm',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.35\\erm']
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.10/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.15/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.20/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.25/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.30/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=1, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.35/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# eiil
# ['/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.10\\eiil',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.15\\eiil',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.20\\eiil',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.25\\eiil',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.30\\eiil',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.35\\eiil']
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.10/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.15/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.20/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.25/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.30/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=True, eiil_infer=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=1, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.35/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# eiil_infer
# ['/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.10\\eiil_infer',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.15\\eiil_infer',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.20\\eiil_infer',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.25\\eiil_infer',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.30\\eiil_infer',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.35\\eiil_infer']
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.10/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.15/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.20/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.25/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.30/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=1, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.35/eiil_infer', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# gray
# ['/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.10\\gray',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.15\\gray',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.20\\gray',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.25\\gray',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.30\\gray',
#  '/EIIL_Research/results/EIIL-3332/label_noise_sweep\\2021-11-05--0.35\\gray']
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.10/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.15/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.20/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.25/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.30/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)
# Namespace(eiil=False, eiil_infer=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=1, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='D:/EIIL_Research/results/EIIL-3332/label_noise_sweep/2021-11-05--0.35/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.1, train_env_2__color_noise=0.2, train_env_3__color_noise=0.3)

# %%
"""Compute confidence intervals to plot."""
means = {'train': defaultdict(list), 'test': defaultdict(list)}
upper_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}
lower_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}

import numpy as np
for method, v in train_accs.items():
  for sigma in label_noises:
    for dset, metrics in {'train': train_accs, 'test': test_accs}.items():
      mean = np.mean(metrics[method][sigma])
      std = np.std(metrics[method][sigma])
      means[dset][method].append(mean)
      upper_bounds[dset][method].append(mean + std)
      lower_bounds[dset][method].append(mean - std)


pprint(means)
# Out:
# {'test': defaultdict(<class 'list'>,
#                      {'eiil': [0.35017502009868623,
#                                0.39765976667404174,
#                                0.42930293679237364,
#                                0.4740774095058441,
#                                0.5000000059604645,
#                                0.5517551898956299],
#                       'eiil_infer': [0.2996199667453766,
#                                      0.34656465947628023,
#                                      0.4285228580236435,
#                                      0.48358836472034455,
#                                      0.5032403290271759,
#                                      0.558655858039856],
#                       'erm': [0.6779477953910827,
#                               0.5219121992588043,
#                               0.3760976105928421,
#                               0.26539653837680816,
#                               0.18780878335237502,
#                               0.5767576694488525],
#                       'gray': [0.8784778594970704,
#                                0.8285528600215912,
#                                0.7787878811359406,
#                                0.728932911157608,
#                                0.6754175543785095,
#                                0.8087809085845947],
#                       'irm': [0.8081208169460297,
#                               0.7557255804538727,
#                               0.683148318529129,
#                               0.6252625286579132,
#                               0.5788478970527648,
#                               0.7261726260185242]}),
#  'train': defaultdict(<class 'list'>,
#                       {'eiil': [0.7992093145847321,
#                                 0.7510015606880188,
#                                 0.7478222012519836,
#                                 0.7135464429855347,
#                                 0.6981180608272552,
#                                 0.9003159403800964],
#                        'eiil_infer': [0.8579434990882874,
#                                       0.8420975208282471,
#                                       0.8300159871578217,
#                                       0.815398782491684,
#                                       0.7925506591796875,
#                                       0.9000152349472046],
#                        'erm': [0.9239535570144654,
#                                0.9032119750976563,
#                                0.8837543547153472,
#                                0.8672587096691131,
#                                0.8481530904769897,
#                                0.9206616282463074],
#                        'gray': [0.8886122643947602,
#                                 0.841477221250534,
#                                 0.792590194940567,
#                                 0.7460551083087921,
#                                 0.6995740473270416,
#                                 0.8263435363769531],
#                        'irm': [0.8710166215896606,
#                                0.8077038824558258,
#                                0.7327573955059051,
#                                0.6780024826526642,
#                                0.6318794071674347,
#                                0.7325453758239746]})}

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import colorConverter as cc
import numpy as np
import seaborn as sns

TITLE_FONTSIZE = 16
AXIS_FONTSIZE = 16
LEGEND_FONTSIZE = 8
FIGSIZE = (4, 4)
SHADING_OPACITY = .5  # how opaque should the uncertainty fills be
LATEX_SYMBOLS = dict(
    erm=r'\textsc{ERM}',
    gray=r'\textsc{Grayscale}',
    irm=r'\textsc{IRM}($e_{\textsc{HC}}$)',
    eiil=r'\textsc{IRM}($e_{\textsc{2ENVS}}| \tilde \Phi = \Phi_{ERM}$)',
    eiil_infer=r'\textsc{IRM}($e_{\textsc{3ENVS}}| \tilde \Phi = \Phi_{ERM}$)',
)


class LegendObject(object):
    def __init__(self, facecolor='red', edgecolor='white', dashed=False):
        self.facecolor = facecolor
        self.edgecolor = edgecolor
        self.dashed = dashed
 
    def legend_artist(self, legend, orig_handle, fontsize, handlebox):
        x0, y0 = handlebox.xdescent, handlebox.ydescent
        width, height = handlebox.width, handlebox.height
        patch = mpatches.Rectangle(
            # create a rectangle that is filled with color
            [x0, y0], width, height, facecolor=self.facecolor,
            # and whose edges are the faded color
            edgecolor=self.edgecolor, lw=3)
        handlebox.add_artist(patch)
 
        # if we're creating the legend for a dashed line,
        # manually add the dash in to our rectangle
        if self.dashed:
            patch1 = mpatches.Rectangle(
                [x0 + 2*width/5, y0], width/5, height, facecolor=self.edgecolor,
                transform=handlebox.get_transform())
            handlebox.add_artist(patch1)
 
        return patch
 
 
def plot_mean_and_CI(label_noise, mean, lb, ub, color_mean=None, color_shading=None):
    # plot the shaded range of the confidence intervals
    plt.fill_between(label_noise, ub, lb,
                     color=color_shading, alpha=.5)
    # plot the mean on top
    plt.plot(label_noise, mean, color=color_mean)
 
# plot the data
a = lambda x: np.array(x)
bg = np.array([1, 1, 1])  # background of the legend is white
for dset in ('train', 'test'):
  from itertools import cycle
  handler_map = dict()
  colors = iter(sns.color_palette("colorblind", len(GLOB_PATTERNS)))
  legend_names = []
  plt.figure(figsize=FIGSIZE)
  for i, method in enumerate(means[dset].keys()):
    legend_names.append(LATEX_SYMBOLS[method])
    color = next(colors)
    color_faded = (np.array(cc.to_rgb(color)) + bg) * SHADING_OPACITY
    handler_map[i] = LegendObject(color, color_faded)
    plot_mean_and_CI(label_noises, 
                     a(means[dset][method]), 
                     a(lower_bounds[dset][method]), 
                     a(upper_bounds[dset][method]),
                     color_mean=color, color_shading=color_faded)
 
  plt.legend(range(len(legend_names)), legend_names, handler_map=handler_map,
             loc='lower left' if dset == 'train' else 'upper right', 
             fontsize=LEGEND_FONTSIZE)
  plt.xlabel(r'Label noise $\sigma_y$', fontsize=AXIS_FONTSIZE)
  plt.ylabel('Accuracy', fontsize=AXIS_FONTSIZE)
  plt.tight_layout()
  plt.ylim((0.3, 0.9))
  plt.xlim((0.1,0.3))
  plt.grid()
  plt.show()
