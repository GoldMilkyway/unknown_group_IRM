# %% [markdown]
# <a href="https://colab.research.google.com/github/ecreager/eiil_dev/blob/public/notebooks/plot_cmnist_label_noise_sweep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Plot results from CMNIST label noise sweep experiments.

See  exps/cmnist.label_noise_sweep.sh for reproducing results.
"""
from collections import defaultdict
from glob import glob
import os
import pickle
from pprint import pprint

import matplotlib.pyplot as plt

def load_results(dirname):
  return pickle.load(open(os.path.join(dirname, 'metrics.p'), 'rb'))
  
def load_flags(dirname):
  return pickle.load(open(os.path.join(dirname, 'flags.p'), 'rb'))

# GLOB_PATTERNS = dict(
#   irm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/irm',
#   erm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/erm',
#   eiil='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil',
#   eiil_cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil_cb',
#   cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/cb',
#   gray='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/gray',
# )

GLOB_PATTERNS = dict(
  irm='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/*/irm',
  erm='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/*/erm',
  eiil='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/*/eiil',
  gray='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/*/gray',
#  cb='/THIS/GLOB/PATTERN/FINDS/ALL/Color-based/RESULTS/DIRS/*/cb',
)

train_accs = defaultdict(dict)
test_accs = defaultdict(dict)
label_noises = set()

for k, v in GLOB_PATTERNS.items():
  print(k)
  pprint(glob(v))
  for dn in glob(v):
    try:
      results = load_results(dn)
      flags = load_flags(dn)
    except:
      print('no metrics or no flags found in', dn)
    label_noises.add(flags.label_noise)
    pprint(flags)
    train_accs[k][flags.label_noise] = results['Train accs']
    test_accs[k][flags.label_noise] = results['Test accs']
#label_noises.remove(0.4)  # less interesting to look at super high noise case
#label_noises.remove(0.45)  # less interesting to look at super high noise case
label_noises = sorted(label_noises)
print(label_noises)
# Out:
# irm
# ['C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.10\\irm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.15\\irm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.20\\irm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.25\\irm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.30\\irm']
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.10/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.15/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.20/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.25/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.30/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# erm
# ['C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.10\\erm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.15\\erm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.20\\erm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.25\\erm',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.30\\erm']
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.10/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.15/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.20/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.25/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.30/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# eiil
# ['C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.10\\eiil',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.15\\eiil',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.20\\eiil',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.25\\eiil',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.30\\eiil']
# Namespace(eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.10/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.15/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.20/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.25/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.30/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# gray
# ['C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.10\\gray',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.15\\gray',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.20\\gray',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.25\\gray',
#  'C:/Program '
#  'Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep\\2021-10-05--0.30\\gray']
# Namespace(eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.10/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.15/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.20/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.25/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='C:/Program Files/Git/scratch/gobi1/creager/opt_env/cmnist/EIIL_Research_results/EIIL_3color_3label_2envs-inferred/label_noise_sweep/2021-10-05--0.30/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# [0.1, 0.15, 0.2, 0.25, 0.3]

# %%
"""Compute confidence intervals to plot."""
means = {'train': defaultdict(list), 'test': defaultdict(list)}
upper_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}
lower_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}

import numpy as np
for method, v in train_accs.items():
  for sigma in label_noises:
    for dset, metrics in {'train': train_accs, 'test': test_accs}.items():
      mean = np.mean(metrics[method][sigma])
      std = np.std(metrics[method][sigma])
      means[dset][method].append(mean)
      upper_bounds[dset][method].append(mean + std)
      lower_bounds[dset][method].append(mean - std)


pprint(means)
# Out:
# {'test': defaultdict(<class 'list'>,
#                      {'eiil': [0.4018799886107445,
#                                0.4140199899673462,
#                                0.5304499924182892,
#                                0.5815999805927277,
#                                0.5276199907064438],
#                       'erm': [0.566079980134964,
#                               0.38695999383926394,
#                               0.24136999249458313,
#                               0.1678899943828583,
#                               0.12747999653220177],
#                       'gray': [0.8766599833965302,
#                                0.8283099830150604,
#                                0.7789799749851227,
#                                0.7293899834156037,
#                                0.675879979133606],
#                       'irm': [0.7682699799537659,
#                               0.73365997672081,
#                               0.6891199827194214,
#                               0.6314499735832214,
#                               0.5848499834537506]}),
#  'train': defaultdict(<class 'list'>,
#                       {'eiil': [0.813989269733429,
#                                 0.7876871347427368,
#                                 0.7683696269989013,
#                                 0.7698985159397125,
#                                 0.7462746024131774],
#                        'erm': [0.929969984292984,
#                                0.9119999766349792,
#                                0.893755978345871,
#                                0.8798299789428711,
#                                0.8672039747238159],
#                        'gray': [0.8898179829120636,
#                                 0.839737993478775,
#                                 0.7922519862651825,
#                                 0.7454499721527099,
#                                 0.6987979888916016],
#                        'irm': [0.873093980550766,
#                                0.8202039897441864,
#                                0.7576240003108978,
#                                0.698775976896286,
#                                0.6475919783115387]})}

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import colorConverter as cc
import numpy as np
import seaborn as sns

TITLE_FONTSIZE = 16
AXIS_FONTSIZE = 16
LEGEND_FONTSIZE = 9
FIGSIZE = (4, 4)
SHADING_OPACITY = .5  # how opaque should the uncertainty fills be
LATEX_SYMBOLS = dict(
    erm=r'\textsc{ERM}',
#    cb=r'$\Phi_{Color}$',
    gray=r'\textsc{Grayscale}',
    irm=r'\textsc{IRM}($e_{\textsc{HC}}$)',
    eiil=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{ERM}$)',
#    eiil_cb=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{Color}$)',
)


class LegendObject(object):
    def __init__(self, facecolor='red', edgecolor='white', dashed=False):
        self.facecolor = facecolor
        self.edgecolor = edgecolor
        self.dashed = dashed
 
    def legend_artist(self, legend, orig_handle, fontsize, handlebox):
        x0, y0 = handlebox.xdescent, handlebox.ydescent
        width, height = handlebox.width, handlebox.height
        patch = mpatches.Rectangle(
            # create a rectangle that is filled with color
            [x0, y0], width, height, facecolor=self.facecolor,
            # and whose edges are the faded color
            edgecolor=self.edgecolor, lw=3)
        handlebox.add_artist(patch)
 
        # if we're creating the legend for a dashed line,
        # manually add the dash in to our rectangle
        if self.dashed:
            patch1 = mpatches.Rectangle(
                [x0 + 2*width/5, y0], width/5, height, facecolor=self.edgecolor,
                transform=handlebox.get_transform())
            handlebox.add_artist(patch1)
 
        return patch
 
 
def plot_mean_and_CI(label_noise, mean, lb, ub, color_mean=None, color_shading=None):
    # plot the shaded range of the confidence intervals
    plt.fill_between(label_noise, ub, lb,
                     color=color_shading, alpha=.5)
    # plot the mean on top
    plt.plot(label_noise, mean, color=color_mean)
 
# plot the data
a = lambda x: np.array(x)
bg = np.array([1, 1, 1])  # background of the legend is white
for dset in ('train', 'test'):
  from itertools import cycle
  handler_map = dict()
  colors = iter(sns.color_palette("colorblind", len(GLOB_PATTERNS)))
  legend_names = []
  plt.figure(figsize=FIGSIZE)
  for i, method in enumerate(means[dset].keys()):
    legend_names.append(LATEX_SYMBOLS[method])
    color = next(colors)
    color_faded = (np.array(cc.to_rgb(color)) + bg) * SHADING_OPACITY
    handler_map[i] = LegendObject(color, color_faded)
    plot_mean_and_CI(label_noises, 
                     a(means[dset][method]), 
                     a(lower_bounds[dset][method]), 
                     a(upper_bounds[dset][method]),
                     color_mean=color, color_shading=color_faded)
 
  plt.legend(range(len(legend_names)), legend_names, handler_map=handler_map,
             loc='lower left' if dset == 'train' else 'lower right', 
             fontsize=LEGEND_FONTSIZE)
  plt.xlabel(r'Label noise $\sigma_y$', fontsize=AXIS_FONTSIZE)
  if dset == 'train':
    plt.ylabel('Accuracy', fontsize=AXIS_FONTSIZE)
  plt.tight_layout()
  plt.ylim((0., 1.))
  plt.grid()
  plt.show()

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import colorConverter as cc
import numpy as np
import seaborn as sns

TITLE_FONTSIZE = 16
AXIS_FONTSIZE = 16
LEGEND_FONTSIZE = 9
FIGSIZE = (4, 4)
SHADING_OPACITY = .5  # how opaque should the uncertainty fills be
LATEX_SYMBOLS = dict(
    erm=r'\textsc{ERM}',
#    cb=r'$\Phi_{Color}$',
    gray=r'\textsc{Grayscale}',
    irm=r'\textsc{IRM}($e_{\textsc{HC}}$)',
    eiil=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{ERM}$)',
#    eiil_cb=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{Color}$)',
)


class LegendObject(object):
    def __init__(self, facecolor='red', edgecolor='white', dashed=False):
        self.facecolor = facecolor
        self.edgecolor = edgecolor
        self.dashed = dashed
 
    def legend_artist(self, legend, orig_handle, fontsize, handlebox):
        x0, y0 = handlebox.xdescent, handlebox.ydescent
        width, height = handlebox.width, handlebox.height
        patch = mpatches.Rectangle(
            # create a rectangle that is filled with color
            [x0, y0], width, height, facecolor=self.facecolor,
            # and whose edges are the faded color
            edgecolor=self.edgecolor, lw=3)
        handlebox.add_artist(patch)
 
        # if we're creating the legend for a dashed line,
        # manually add the dash in to our rectangle
        if self.dashed:
            patch1 = mpatches.Rectangle(
                [x0 + 2*width/5, y0], width/5, height, facecolor=self.edgecolor,
                transform=handlebox.get_transform())
            handlebox.add_artist(patch1)
 
        return patch
 
 
def plot_mean_and_CI(label_noise, mean, lb, ub, color_mean=None, color_shading=None):
    # plot the shaded range of the confidence intervals
    plt.fill_between(label_noise, ub, lb,
                     color=color_shading, alpha=.5)
    # plot the mean on top
    plt.plot(label_noise, mean, color=color_mean)
 
# plot the data
a = lambda x: np.array(x)
bg = np.array([1, 1, 1])  # background of the legend is white
for dset in ('train', 'test'):
  from itertools import cycle
  handler_map = dict()
  colors = iter(sns.color_palette("colorblind", len(GLOB_PATTERNS)))
  legend_names = []
  plt.figure(figsize=FIGSIZE)
  for i, method in enumerate(means[dset].keys()):
    legend_names.append(LATEX_SYMBOLS[method])
    color = next(colors)
    color_faded = (np.array(cc.to_rgb(color)) + bg) * SHADING_OPACITY
    handler_map[i] = LegendObject(color, color_faded)
    plot_mean_and_CI(label_noises, 
                     a(means[dset][method]), 
                     a(lower_bounds[dset][method]), 
                     a(upper_bounds[dset][method]),
                     color_mean=color, color_shading=color_faded)
 
  plt.legend(range(len(legend_names)), legend_names, handler_map=handler_map,
             loc='lower left' if dset == 'train' else 'lower right', 
             fontsize=LEGEND_FONTSIZE)
  plt.xlabel(r'Label noise $\sigma_y$', fontsize=AXIS_FONTSIZE)
  if dset == 'train':
    plt.ylabel('Accuracy', fontsize=AXIS_FONTSIZE)
  plt.tight_layout()
  plt.ylim((0.3, 1.))
  plt.grid()
  plt.show()
